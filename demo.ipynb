# %%
from PIL import Image
import numpy as np

# %%
img1 = Image.open('data/AZ9010_256/Z_RADR_I_Z9010_20190601002401_P_DOR_SA_R_10_230_15.010_clean.png')

# %%
img2 = Image.open('data/AZ9010_256/Z_RADR_I_Z9010_20190601003000_P_DOR_SA_R_10_230_15.010_clean.png')

# %%
img3 = Image.open('data/AZ9010_256/Z_RADR_I_Z9010_20190601003601_P_DOR_SA_R_10_230_15.010_clean.png')

# %%
image = np.concatenate((img1,img2,img3),axis=0)

# %%
image = image.reshape(3,256,256)

# %%
a =Image.fromarray(np.transpose(image, (1,2,0)), mode="RGB")

# %%
image.shape
# Out:
# (3, 256, 256)

# %%
a
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7EFC35178BE0>

# %%
b = np.array(a)

# %%
# Out:
# (256, 256, 3)

# %%
b.dtype
# Out:
# dtype('uint8')

# %%
c = Image.open('test.png')

# %%
pic = np.array(c)

# %%
# Out:
# (256, 256, 3)

# %%
import matplotlib.pyplot as plt

# %%
c = np.transpose(pic, (2,0,1))

# %%
plt.imshow(pic)

# %%
plt.imshow(pic[:,:,2])
